# %% [markdown]
# # Day 6 - Model Explainability And Risk Scoring\n\nThis notebook runs the Day 6 risk scoring and explainability workflows.

# %%
from src.models.predict import run_prediction\n\nrisk_scores = run_prediction()\nrisk_scores.head()

# %%
from src.explainability.shap_analysis import run_explainability\n\nfeature_importance = run_explainability()\nfeature_importance.head(10)

# %% [markdown]
# Outputs created by this workflow:\n\n- `data/predictions/delivery_risk_scores.csv`\n- `reports/model_feature_importance.csv`\n- `reports/model_explainability_report.md`\n- `reports/day6_dashboard_summary.md`
