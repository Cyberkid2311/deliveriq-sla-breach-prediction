# %% [markdown]
# # Day 5 - Advanced Model Training\n\nThis notebook runs the Day 5 advanced modeling workflow and saves the final selected model.

# %%
from src.models.train_model import run_training\n\nselected_thresholds = run_training()\nselected_thresholds

# %% [markdown]
# Outputs created by this workflow:\n\n- `models/final_model.pkl`\n- `reports/advanced_model_report.md`\n- `docs/day5_model_selection_notes.md`
